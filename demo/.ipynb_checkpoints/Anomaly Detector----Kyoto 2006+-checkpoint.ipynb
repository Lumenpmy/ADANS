# %% [markdown]
# ## Intro
# This code will show the whole code flow of our proposed ADANS method. For the Kyoto 2006+ dataset, we use the AutoEncoder anomaly detection model.

# %%
# %load_ext autoreload
# %autoreload 2
#表示每次Import导入的都是最新的模块，在修改代码后不用刷新kernel
# %matplotlib notebook
## import packages
import sys
sys.path.append('../moudles/')
#这个baselines代码中不存在
sys.path.append('../')
import numpy as np
from sklearn.preprocessing import MinMaxScaler
import _pickle as pkl
import AE
import torch
from ShiftScreener import ShiftScreener
from ShiftDetector import ShiftDetector
from ShiftAdapter import ShiftAdapter
import myutils as utils
import random

# %% [markdown]
# ## Prepare AutoEncoder model and data

# %%
utils.set_random_seed()
feat = np.load('./data/2007.npz')
X, y = feat['X'], feat['y']
X_ben = X[y==0]
train_num=50000
X_train = X_ben[:train_num]
scaler = MinMaxScaler().fit(X_train)
X_train = scaler.transform(X_train)
feature_size=X_train.shape[-1]
model,thres= AE.train(X_train,feature_size)
# Out:
# epoch:0/10 |Loss: 0.013792422600090504
# epoch:1/10 |Loss: 0.013447404839098454
# epoch:2/10 |Loss: 0.013002714142203331
# epoch:3/10 |Loss: 0.012609494850039482
# epoch:4/10 |Loss: 0.012191148474812508
# epoch:5/10 |Loss: 0.011781789362430573
# epoch:6/10 |Loss: 0.011332525871694088
# epoch:7/10 |Loss: 0.010742062702775002
# epoch:8/10 |Loss: 0.009929811581969261
# epoch:9/10 |Loss: 0.008891166187822819
# max AD score 0.1436113

# %%
FEAT_0 = np.load('./data/2007.npz')
X_0, y_0 = scaler.transform(FEAT_0['X']), FEAT_0['y']
FEAT_1 = np.load('./data/2011.npz')
X_1, y_1 = scaler.transform(FEAT_1['X']), FEAT_1['y']

# %% [markdown]
# ## See how AE performs on new data (data where normality shifts occur) and old data (data where normality shifts do not occur)

# %%
print('****************************** Before Normality Shift occurs ******************************')
y_pred_0, y_prob_0 = AE.test(model, thres, X_0)
utils.TPR_FPR(y_prob_0, y_0, thres)
# Out:
# ****************************** Before Normality Shift occurs ******************************
# *********************** The relevant test indicators are as follows ***********************
# TP 18614
# FP 2971
# TN 297029
# FN 81386
# Precision: 0.8623581190641649
# Recall: 0.18614
# F1_Score: 0.3061890858247317
# Accuracy: 0.7891075

# %%
print('****************************** After Normality Shift occurs ******************************')
y_pred_1, y_prob_1 = AE.test(model, thres, X_1)
utils.TPR_FPR(y_prob_1, y_1, thres)
# Out:
# ****************************** After Normality Shift occurs ******************************
# *********************** The relevant test indicators are as follows ***********************
# TP 7297
# FP 8229
# TN 291770
# FN 92704
# Precision: 0.4699858302202757
# Recall: 0.07296927030729693
# F1_Score: 0.12632544773083348
# Accuracy: 0.7476675

# %% [markdown]
# **Apparently, the new data has 39.2% drop in Precision metrics, 11.3% drop in Recall metrics, 18.0% drop in F1-score and 4.1% drop in Accuracy, proving that the performance of the anomaly detection model is significantly degraded on the new data.
# Next let's use ADANS to solve the problem of anomaly detection models facing normality shift**

# %% [markdown]
# ## Let's use ADANS！

# %% [markdown]
# ## Selection the representative samples from old and new data using Normality Shift Screener and filter out anomalous samples from them according labeling cost.

# %%
# 新旧数据各自有30万个正常样本，10万个异常样本
vali_num = 100000
X_0_normal=X_0[y_0==0]
y_0_normal=y_0[y_0==0]
y_prob_0_normal=y_prob_0[y_0==0]
utils.set_random_seed()
# 随机选择10万个样本，旧数据只有正常的，新数据混合有正常和异常的样本
random_sequence_o = random.sample(range(0,len(X_0_normal)), vali_num)
rmse_o = y_prob_0_normal[random_sequence_o]
X_o_normal = X_0_normal[random_sequence_o]
y_o_normal=y_0_normal[random_sequence_o]

random_sequence_n = random.sample(range(0,len(X_1)), vali_num)
X_n = X_1[random_sequence_n]
rmse_n = y_prob_1[random_sequence_n]
y_n=y_1[random_sequence_n]

# Number of anomalous samples included in 100,000 samples of old data
j=0
for i in range(100000):
    if(y_o_normal[i]==1):
        j=j+1
print(j)
# Number of anomalous samples contained in 100,000 samples of incoming data
m=0
for i in range(100000):
    if(y_n[i]==1):
        m=m+1
print(m)
# 选择出的10万个新数据中有24788个异常样本
# Out:
# 0
# 24788

# %%
# import time
# %matplotlib inline

# start_time = time.time()
old_num = 50000
label_num = 10000
labeling_probability=label_num/vali_num
print('The labing cost is：',labeling_probability)
scranner = ShiftScreener(model, X_o_normal, X_n, y_n, old_num, label_num,X_1)
result = scranner.RMSE_Kmeans()
# end_time = time.time()
# print(f"执行时间：{end_time - start_time} 秒")
X_o_rep_nor=result[0]
X_n_rep_nor=result[2]
# Out:
# The labing cost is： 0.1
# NOTICE: simulating labelling...
# Filter 4883 anomalies in X_n_rep
#  (label_num:10000, X_n_rep_normal:5117, X_n:100000)

# %% [markdown]
# ## Detection of normality shift using Normality Shift Detector

# %%
import numpy as np
X_o_rep_nor_np=X_o_rep_nor.numpy()
X_n_rep_nor_np=X_n_rep_nor.numpy()

utils.set_random_seed()
sd = ShiftDetector(method='min_max')
print("Amplify differences between values that differ between rmse_o")
_, rmse_o_rep_nor = AE.test(model, thres, X_o_rep_nor_np[:len(X_n_rep_nor_np)])
score_o_rep_nor=sd.process(rmse_o_rep_nor)
print("Amplify differences between values that differ between rmse_n")
_, rmse_n_rep_nor = AE.test(model, thres, X_n_rep_nor_np)
score_n_rep_nor=sd.process(rmse_n_rep_nor)
t = utils.get_params('ShiftDetector')['test_thres']
p_value = sd.Monte_Carlo(score_o_rep_nor,score_n_rep_nor)[0]
if p_value >= t:
    print("No normality shift!", p_value)
else:
    print('Shift! P-value is', p_value)
# Out:
# Amplify differences between values that differ between rmse_o
# 均值： 0.494831919670105
# 方差： 0.01388363167643547
# Amplify differences between values that differ between rmse_n
# 均值： 0.21621228754520416
# 方差： 0.021421300247311592
# Wasserstein distance between old set and new set is: 0.2786210035124074
# Shift! P-value is 0.000999000999000999

# %%
# 画出的频率分布直方图和经过光滑设置的折线图
print("Visualize Shift:")
sd.visualize_hists(score_o_rep_nor,score_n_rep_nor)
# Out:
# Visualize Shift:

# %% [markdown]
# ## Adaption of normality shift using Normality Shift Adapter

# %%
utils.set_random_seed()
adapter=ShiftAdapter(model,X_o_rep_nor,X_n_rep_nor,feature_size,thres*0.01,labeling_probability)
adapter.update_AE()
# Out:
# epoch:0/20
# old_domain_classfiy_loss: 0.33759021759033203 new_domain_classfiy_loss: 0.35489025712013245 domain_classfiy_loss: 0.6924804449081421
# label_predictor_loss 0.08459925651550293
# epoch:1/20
# old_domain_classfiy_loss: 0.4231436252593994 new_domain_classfiy_loss: 0.16817793250083923 domain_classfiy_loss: 0.591321587562561
# label_predictor_loss 0.11863536387681961
# epoch:2/20
# old_domain_classfiy_loss: 0.015399593859910965 new_domain_classfiy_loss: 1.5450859069824219 domain_classfiy_loss: 1.5604854822158813
# label_predictor_loss 1.1486117839813232
# epoch:3/20
# old_domain_classfiy_loss: 0.1252540946006775 new_domain_classfiy_loss: 2.446120023727417 domain_classfiy_loss: 2.5713741779327393
# label_predictor_loss 4.534421443939209
# epoch:4/20
# old_domain_classfiy_loss: 0.3228432834148407 new_domain_classfiy_loss: 0.4029068648815155 domain_classfiy_loss: 0.7257501482963562
# label_predictor_loss 5.212036609649658
# epoch:5/20
# old_domain_classfiy_loss: 0.327577143907547 new_domain_classfiy_loss: 0.36632028222084045 domain_classfiy_loss: 0.6938974261283875
# label_predictor_loss 1.5963702201843262
# epoch:6/20
# old_domain_classfiy_loss: 0.33078238368034363 new_domain_classfiy_loss: 0.3628799021244049 domain_classfiy_loss: 0.6936622858047485
# label_predictor_loss 0.2438320517539978
# epoch:7/20
# old_domain_classfiy_loss: 0.33385995030403137 new_domain_classfiy_loss: 0.3596188724040985 domain_classfiy_loss: 0.6934788227081299
# label_predictor_loss 0.1174984723329544
# epoch:8/20
# old_domain_classfiy_loss: 0.3366852104663849 new_domain_classfiy_loss: 0.35666146874427795 domain_classfiy_loss: 0.6933466792106628
# label_predictor_loss 4.566801071166992
# epoch:9/20
# old_domain_classfiy_loss: 0.33918505907058716 new_domain_classfiy_loss: 0.3540728688240051 domain_classfiy_loss: 0.6932579278945923
# label_predictor_loss 0.11532755196094513
# epoch:10/20
# old_domain_classfiy_loss: 0.34131795167922974 new_domain_classfiy_loss: 0.354162335395813 domain_classfiy_loss: 0.6954802870750427
# label_predictor_loss 0.11463169753551483
# epoch:11/20
# old_domain_classfiy_loss: 0.34307387471199036 new_domain_classfiy_loss: 0.3500979244709015 domain_classfiy_loss: 0.6931717991828918
# label_predictor_loss 0.11350461840629578
# epoch:12/20
# old_domain_classfiy_loss: 0.34445714950561523 new_domain_classfiy_loss: 0.3486991226673126 domain_classfiy_loss: 0.6931562423706055
# label_predictor_loss 10.376598358154297
# epoch:13/20
# old_domain_classfiy_loss: 0.3454964756965637 new_domain_classfiy_loss: 0.34765297174453735 domain_classfiy_loss: 0.6931494474411011
# label_predictor_loss 5.846601486206055
# epoch:14/20
# old_domain_classfiy_loss: 0.34623339772224426 new_domain_classfiy_loss: 0.3469139635562897 domain_classfiy_loss: 0.6931473612785339
# label_predictor_loss 9.247675895690918
# epoch:15/20
# old_domain_classfiy_loss: 0.3467167019844055 new_domain_classfiy_loss: 0.3464304804801941 domain_classfiy_loss: 0.6931471824645996
# label_predictor_loss 0.10974061489105225
# epoch:16/20
# old_domain_classfiy_loss: 0.3469974398612976 new_domain_classfiy_loss: 0.34615007042884827 domain_classfiy_loss: 0.6931475400924683
# label_predictor_loss 0.10864299535751343
# epoch:17/20
# old_domain_classfiy_loss: 0.34712526202201843 new_domain_classfiy_loss: 0.3460225462913513 domain_classfiy_loss: 0.6931477785110474
# label_predictor_loss 0.10792481899261475
# epoch:18/20
# old_domain_classfiy_loss: 0.34714511036872864 new_domain_classfiy_loss: 0.34600260853767395 domain_classfiy_loss: 0.6931477189064026
# label_predictor_loss 18.10433578491211
# epoch:19/20
# old_domain_classfiy_loss: 0.34709566831588745 new_domain_classfiy_loss: 0.3460521101951599 domain_classfiy_loss: 0.6931477785110474
# label_predictor_loss 2.956622838973999

# %% [markdown]
# ## Re-testing the performance of the anomaly detection model (AE) on new data

# %%
print('After OWAD Adaptation @2011:')
y_pred, y_prob = AE.test(adapter.updated_AE,thres, X_1)
utils.TPR_FPR(y_prob, y_1, thres)
# Out:
# After OWAD Adaptation @2011:
# *********************** The relevant test indicators are as follows ***********************
# TP 46168
# FP 35901
# TN 264098
# FN 53833
# Precision: 0.5625510241382251
# Recall: 0.4616753832461675
# F1_Score: 0.5071456033393751
# Accuracy: 0.775665

# %% [markdown]
# **(As we can see that, ADANS improves the Precision from 0.47 to 0.56, the Recall from 0.07 to 0.46, the F1-score from 0.13 to 0.51 and the Accuracy from 0.75 to 0.78 with 10k labels, which is 10% of validation set)**

# %% [markdown]
# ## Contrasting methods: retraining
# A common practice to tackle concept drift is to retrain the model with both old and new samples. Here we'll show whether retraining works in this example.

# %%
utils.set_random_seed()
random_sequence_1 = random.sample(range(0,len(X_0)), train_num)
random_sequence_2 = random.sample(range(0,len(X_0)), label_num)
X_retrain = np.concatenate((X_0[random_sequence_1],X_1[random_sequence_2]))
retrain_model,retrain_thres=AE.train(X_retrain, X_retrain.shape[-1])
print('****************************** After Retraining ******************************')
y_pred, y_prob = AE.test(retrain_model, retrain_thres, X_1)
utils.TPR_FPR(y_prob, y_1, thres)
# Out:
# epoch:0/10 |Loss: 0.013748949393630028
# epoch:1/10 |Loss: 0.013266904279589653
# epoch:2/10 |Loss: 0.01297968253493309
# epoch:3/10 |Loss: 0.01256039459258318
# epoch:4/10 |Loss: 0.012030394747853279
# epoch:5/10 |Loss: 0.011496317572891712
# epoch:6/10 |Loss: 0.010689262300729752
# epoch:7/10 |Loss: 0.009915702044963837
# epoch:8/10 |Loss: 0.009042223915457726
# epoch:9/10 |Loss: 0.008672844618558884
# max AD score 0.14573845
# ****************************** After Retraining ******************************
# *********************** The relevant test indicators are as follows ***********************
# TP 5291
# FP 8388
# TN 291611
# FN 94710
# Precision: 0.38679728050296075
# Recall: 0.052909470905290946
# F1_Score: 0.09308585503166784
# Accuracy: 0.742255

# %% [markdown]
# **(As we can see that, Retraining actually has a negtive effect. Please refer to our paper for more analysis)**
